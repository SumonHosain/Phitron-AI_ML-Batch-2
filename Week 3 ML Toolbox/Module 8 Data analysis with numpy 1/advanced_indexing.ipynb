# %%
import numpy as np
list = list(range(1,10))
arr = np.array(list)

# %%
lst = arr[[1,2,3]]
print(lst)
# Out:
# [2 3 4]

# %%
arr2=np.array([[1,3,4]
               ,[1,2,3],
               [21,2,4],
               [1,2,5]])
print(arr2)
# Out:
# [[ 1  3  4]
#  [ 1  2  3]
#  [21  2  4]
#  [ 1  2  5]]

# %%
#arr[[rows],[columns]]
print(arr2[[1,2],[1,1]])
# Out:
# [2 2]
# [ 3 21]

# %%
print(arr2[arr2>2])
# Out:
# [ 3  4  3 21  4  5]

# %%
#iteration in array
for i in np.nditer(arr2):
    print(i)
# Out:
# 1
# 3
# 4
# 1
# 2
# 3
# 21
# 2
# 4
# 1
# 2
# 5
