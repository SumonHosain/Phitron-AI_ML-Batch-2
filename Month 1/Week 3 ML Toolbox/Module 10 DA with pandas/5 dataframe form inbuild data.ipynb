# %%
import pandas as pd

# %%
list = [['Alice',25],['Hel',20],['Nice',15]]
my_list = pd.DataFrame(list,columns=['Name','Age'],index=[1,2,3])
print(my_list)
print(type(my_list))
# Out:
#     Name  Age
# 1  Alice   25
# 2    Hel   20
# 3   Nice   15
# <class 'pandas.core.frame.DataFrame'>

# %%
tuple = (('alice',20),('Jamsed',30),('Nondeni',15))
my_tuple = pd.DataFrame(tuple,columns=['Name','Age'],index = [1,2,3])
print(my_tuple)
# Out:
#       Name  Age
# 1    alice   20
# 2   Jamsed   30
# 3  Nondeni   15

# %%
dict = {
    'Name':['Samad','Alice','Nondeni'],
    'Age':[20,50,30]
}

my_dict = pd.DataFrame(dict)
print(my_dict)
# Out:
#       Name  Age
# 0    Samad   20
# 1    Alice   50
# 2  Nondeni   30

# %%
data = [
    {'Name':'Sumon','age':22,'city':'satkhira'},
    {'Name':'Rana','age':22}
]
my_data = pd.DataFrame(data)
print(my_data)
# Out:
#     Name  age      city
# 0  Sumon   22  satkhira
# 1   Rana   22       NaN
