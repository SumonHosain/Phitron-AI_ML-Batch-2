# %%
import numpy as np

# %%
arr = np.random.randint(1,100,size=(100))

# %%
value_greater_than_10 = np.count_nonzero(arr==40)
print(value_greater_than_10)
# Out:
# 3

# %%
uniqe_value,count = np.unique(arr,return_counts=True)
print(uniqe_value,count)
# Out:
# [ 3  4  7  9 10 12 13 14 15 16 17 19 23 24 25 29 30 31 32 33 35 36 37 38
#  39 40 43 44 47 48 49 51 55 56 57 58 59 60 65 66 67 69 73 74 75 77 78 79
#  80 81 82 83 86 87 88 89 90 91 92 93 94 95 96 98 99] [1 2 1 3 1 1 2 3 1 1 1 1 3 1 1 1 2 2 3 1 1 1 1 1 1 3 2 1 2 1 1 1 1 2 1 1 1
#  2 1 2 1 1 1 2 2 3 2 2 2 1 2 1 4 1 1 3 1 1 1 1 2 2 1 2 1]
