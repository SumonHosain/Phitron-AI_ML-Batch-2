# %%
import numpy as np

# %%
math = np.array([
    [1,2,3,5],
    [2,4,3,5]
])

# %%
transpose = math.T
print(transpose)
# Out:
# [[1 2]
#  [2 4]
#  [3 3]
#  [5 5]]

# %%
a = np.random.randint(1,10, size=(10))
splited = np.array_split(a,2)
print(splited)
# Out:
# [array([5, 5, 8, 8, 2], dtype=int32), array([4, 2, 3, 7, 7], dtype=int32)]
