# %%
# lamda function 
# lamda arguments: expression
add = lambda a,b: a+b
add(2,3)
# Out:
# 5

# %%
numbers = [1, 2, 3, 4]
result = list(map(lambda x: x * 2, numbers))
print(result)
# Out:
# [2, 4, 6, 8]

# %%
# these two are similar but second one is not enable to work
numbers = [1,2,3,4,5]
result = map(lambda x:x*2, numbers)
print(list(result))

'''def hello(**x):
    for i in x.items():
        print(i[1]*2)
hello(a=1,b=2,c=3,d=4,e=5)

result_2 = list(map(lambda y:y*2, hello()))'''
# Out:
# [2, 4, 6, 8, 10]
# 'def hello(**x):\n    for i in x.items():\n        print(i[1]*2)\nhello(a=1,b=2,c=3,d=4,e=5)\n\nresult_2 = list(map(lambda y:y*2, hello()))'
