# %%
def adder(a,b,c):
    print(f'{a},{b},{c}')
adder(a=10,b=20,c=30)
# Out:
# 10,20,30

# %%
def adder(**argws):
    for kew,value in argws.items():
        print(f'{kew}:{value}')

adder(a=10, b=20, c=30)
# Out:
# a:10
# b:20
# c:30
