# %%
with open('write_read.txt','w+') as file:
    file.write('Hello World')
    print(file.tell())
    file.seek(5)
    print(file.read())
    file.truncate(5)
    file.seek(0)
    print(file.read())
# Out:
# 11
#  World
# Hello
