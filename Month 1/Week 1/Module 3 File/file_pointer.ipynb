# %%
with open('sample.txt') as file:
    file.read()
    print(file.tell())
# Out:
# 11

# %%
with open('sample.txt') as file:
    file.read(5)
    print(file.tell())
    
    x=file.read(4)
    
    print(x)
    print(file.tell())
# Out:
# 5
#  wor
# 9

# %%
#seek
with open('sample.txt') as file:
    file.read()
    print(file.tell())
    
    file.seek(3)
    print(file.tell())
# Out:
# 11
# 3
