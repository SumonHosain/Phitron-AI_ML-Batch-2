# %%
file = open('sample.txt','r')
'''content = file.readlines()''' # creates a list for text
content = file.readlines()
new_content =list(map(str.strip,content))
filter_content = list(filter(lambda x:len(x)>3, new_content))
filter_content
# Out:
# ['hello world', 'where you from', 'how is going']

# %%
with open('sample.txt') as file:
    content = file.read()
    print(content)

file.closed
# Out:
# hello world
# where you from
# True

# %%
with open('sample.txt') as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open('sample.tt') as file:
#       2     content = file.read()
#       4     content = file.readlines()
#
# File c:\Users\sumon\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.tt'
