# %%
class Phone:
    def __init__(self,model,battery):
        self.model=model
        self.__battery = 100

    def get_battery(self):
        return self.__battery

a = Phone('Motorola')
a.model
a.get_battery()
# Out:
# 100

# %%
class SmartPhone():
    pass

# %%
class GamingPhone():
    pass
