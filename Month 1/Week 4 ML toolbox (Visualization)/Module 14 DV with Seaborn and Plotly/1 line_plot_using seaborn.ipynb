# %%
import seaborn as sns
import pandas as pd

# %%
student = pd.read_csv('C:/Users/sumon/Phitron-AI_ML-Batch-2/Phitron-AI_ML-Batch-2/Week 4 ML toolbox (Visualization)/Module 14 DV with Seaborn and Plotly/Data/sns_data .csv')

# %%
student
# Out:
#     student_id class_level   subject  study_hours  test_score  week  \
# 0            1    Freshman      Math            5          78     1
# 1            2    Freshman   Science            3          65     1
# 2            3    Freshman   History            4          70     1
# 3            4    Freshman  Language            2          60     1
# 4            5   Sophomore      Math            6          82     1
# ..         ...         ...       ...          ...         ...   ...
# 90          91      Junior      Math            7          85     6
# 91          92      Junior   Science            6          78     6
# 92          93      Junior   History            5          72     6
# 93          94      Junior  Language            4          68     6
# 94          95      Senior      Math            6          84     6
#
#     attendance_rate  gender  hostel  Tshirt_size
# 0                90    Male    True           30
# 1                80  Female   False           20
# ...

# %%
# axis level can contain only one graph (axis)
sns.lineplot(data=student,x=student['week'], y=student['attendance_rate'],errorbar=None)
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
sns.lineplot(data=student,x=student['week'], y=student['attendance_rate'],errorbar=None,hue='gender')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
# figure level can contain multiple graph(axis)
sns.relplot(kind='line',data=student,x=student['week'], y=student['attendance_rate'],errorbar=None,hue='gender')

# %%
sns.relplot(kind='line',data=student,x='week', y='attendance_rate',errorbar=None,hue='class_level')

# %%
sns.countplot(data=data,x=)
