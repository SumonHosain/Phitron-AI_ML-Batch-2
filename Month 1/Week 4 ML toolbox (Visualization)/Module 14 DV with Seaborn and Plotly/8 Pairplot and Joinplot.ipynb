# %%
import pandas as pd
import seaborn as sns

# %%
student = pd.read_csv('C:/Users/sumon/Phitron-AI_ML-Batch-2/Phitron-AI_ML-Batch-2/Week 4 ML toolbox (Visualization)/Module 14 DV with Seaborn and Plotly/Data/student_dataset_complete.csv')

student
# Out:
#     number_courses  time_study   Marks  student_id  class_level  subject  \
# 0                3       4.508  19.202           1           10  Science
# 1                4       0.096   7.734           2           12     Math
# 2                4       3.133  13.811           3           11  Science
# 3                6       7.909  53.018           4           10  Science
# 4                8       7.811  55.299           5           11  English
# ..             ...         ...     ...         ...          ...      ...
# 95               6       3.561  19.128          96           11  English
# 96               3       0.301   5.609          97           10  Science
# 97               4       7.163  41.444          98           11     Math
# 98               7       0.309  12.027          99           12     Math
# 99               3       6.335  32.357         100           12  Science
#
#     study_hours  test_score  week  attendance_rate gender  hostel  \
# 0         4.508      19.202     2             0.89      F       0
# 1         0.096       7.734     3             0.98      M       0
# 2         3.133      13.811     5             0.83      F       0
# 3         7.909      53.018     4             0.92      F       1
# 4         7.811      55.299     3             0.80      M       1
# ..          ...         ...   ...              ...    ...     ...
# 95        3.561      19.128     4             0.94      F       1
# 96        0.301       5.609     2             0.83      M       1
# 97        7.163      41.444     3             0.97      M       0
# 98        0.309      12.027     1             0.98      F       0
# 99        6.335      32.357     5             0.95      M       1
#
#     Tshirt_size class_name
# 0             2  Sophomore
# 1             3     Senior
# 2             3     Junior
# 3             4  Sophomore
# 4             4     Junior
# ..          ...        ...
# 95            3     Junior
# 96            3  Sophomore
# 97            1     Junior
# 98            1     Senior
# 99            2     Senior
#
# [100 rows x 14 columns]

# %%
student = student[['study_hours','attendance_rate','test_score','gender']]

# %%
student
# Out:
#     study_hours  attendance_rate  test_score gender
# 0         4.508             0.89      19.202      F
# 1         0.096             0.98       7.734      M
# 2         3.133             0.83      13.811      F
# 3         7.909             0.92      53.018      F
# 4         7.811             0.80      55.299      M
# ..          ...              ...         ...    ...
# 95        3.561             0.94      19.128      F
# 96        0.301             0.83       5.609      M
# 97        7.163             0.97      41.444      M
# 98        0.309             0.98      12.027      F
# 99        6.335             0.95      32.357      M
#
# [100 rows x 4 columns]

# %%
sns.pairplot(data=student)

# %%
sns.pairplot(data=student,hue='gender')

# %%
sns.jointplot(data=student,x='study_hours',y='test_score')
