# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hours = [1,4,3,5,2]
days =[1,2,3,4,5]
plt.plot(days,hours)

# %%
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.title('Study time of a Student over time')
plt.plot(days,hours)

# %%
hours = [1,4,3,5,2]
hours_1 = [1,5,3,9,7]
days =[1,2,3,4,5]
plt.plot(days,hours)
plt.plot(days,hours_1)
