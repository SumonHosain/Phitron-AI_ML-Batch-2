# %%
import pandas as pd

# %%
data = {
    'Name':['Sumon','Rana','Akij','Samsung','Rana'],
    'City':['Satkhira','khulna','Motijhil Moddhopara Dhaka','Dhaka Motijhil','khulna'],
    'Department': ['Hr','President','Company','hel','President'],
    'Saalry':[1000,200,24444,20,200]
}
df = pd.DataFrame(data)

# %%
# finding uniqe value in name col
len(df['Name'].unique())
# Out:
# array(['Sumon', 'Rana', 'Akij', 'Samsung'], dtype=object)

# %%
#nunique() doesnot count nan vlaues where len() does
df['Name'].nunique()
# Out:
# 4

# %% [markdown]
# Checking Null

# %%
df = pd.read_csv('new_Data.csv')
df
# Out:
#     Unnamed: 0 StudentID          FullName  Data Structure Marks  \
# 0            0    PH1001       Alif Rahman                  85.0
# 1            1    PH1002     Fatima Akhter                  92.0
# 2            2    PH1003     Imran Hossain                  88.0
# 3            3    PH1004  Jannatul Ferdous                  78.0
# 4            4    PH1005       Kamal Uddin                   NaN
# 5            5    PH1006       Laila Begum                  75.0
# 6            6    PH1007    Mahmudul Hasan                  80.0
# 7            7    PH1008       Nadia Islam                  81.0
# 8            8    PH1009        Omar Faruq                  72.0
# 9            9    PH1010      Priya Sharma                  89.0
# 10          10    PH1011      Rahim Sheikh                   NaN
# 11          11    PH1012   Sadia Chowdhury                  85.0
# 12          12    PH1013      Tanvir Ahmed                  75.0
# ...

# %%
df['Algorithm Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Algorithm Marks, dtype: bool

# %%
df['Algorithm Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Algorithm Marks, dtype: bool

# %%
df['Algorithm Marks'].hasnans
# Out:
# True
